# %%
import numpy as np 
import pandas as pd 
import DataPreProcess as dp
import warnings
import os
import matplotlib.pyplot as plt
# %matplotlib inline
os.chdir('D:/工作/data/shibie/')
warnings.filterwarnings('ignore')

train_data = pd.read_csv('train_data.csv')
test =pd.read_csv('test.csv')

# %%
constant = dp.Constant()
miss = dp.Missing(delete=0.8, indicator=0.6)

# %%
cat_fet = ['经营期限至', '邮政编码', 
         '核准日期', '注销时间', '经营期限自', '成立日期', '经营范围']
constant.plot_frequency(train_data[cat_fet])

# %%
constant.check_constant(train_data)
# Out:
# Index([], dtype='object')

# %%
miss.plot_item_miss(train_data)
